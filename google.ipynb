# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the data
df=pd.read_csv('google (1).xls')

# %%
# chek 5 row
df.head()
# Out:
#    id_x                          name   brand             variant category  \
# 0     0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1     0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2     0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 3     0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 4     0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  user_id  ga_session_id country   device            type  \
# 0            14    11155           4933      US   mobile  begin_checkout
# 1            14     7297            157      CA   mobile        purchase
# 2            14    28932            773      TW  desktop     add_to_cart
# 3            14    28932            773      TW  desktop        purchase
# 4            14     5367           3710      US  desktop        purchase
#
#    item_id                 date    id_y  ltv
# ...

# %%
# chek dtype and non null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28369 entries, 0 to 28368
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           28369 non-null  int64
#  1   name           28369 non-null  object
#  2   brand          28369 non-null  object
#  3   variant        4416 non-null   object
#  4   category       28369 non-null  object
#  5   price_in_usd   28369 non-null  int64
#  6   user_id        28369 non-null  int64
#  7   ga_session_id  28369 non-null  int64
#  8   country        28312 non-null  object
#  9   device         28369 non-null  object
#  10  type           28369 non-null  object
#  11  item_id        28369 non-null  int64
#  12  date           28369 non-null  object
#  13  id_y           28369 non-null  int64
#  14  ltv            28369 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.2+ MB

# %%
# chek the numerical columns mean,std,minnium value,max value,persentyle
df.describe()
# Out:
#                id_x  price_in_usd        user_id  ga_session_id       item_id  \
# count  28369.000000  28369.000000   28369.000000   28369.000000  28369.000000
# mean     888.338574     24.949240   27776.645282    3537.997920    888.338574
# std      285.176861     20.893197   51537.587588    3840.004136    285.176861
# min        0.000000      1.000000       1.000000       0.000000      0.000000
# 25%      915.000000     12.000000    8401.000000     633.000000    915.000000
# 50%      972.000000     22.000000   17027.000000    2109.000000    972.000000
# 75%     1039.000000     30.000000   25801.000000    5165.000000   1039.000000
# max     1371.000000    313.000000  270137.000000   18007.000000   1371.000000
#
#                 id_y           ltv
# count   28369.000000  28369.000000
# mean   132633.770595      1.425923
# std     76956.277532     14.994183
# min        99.000000      0.000000
# 25%     65533.000000      0.000000
# 50%    126080.000000      0.000000
# ...

# %%
# chek the null value
df.isnull().sum()
# Out:
# id_x                 0
# name                 0
# brand                0
# variant          23953
# category             0
# price_in_usd         0
# user_id              0
# ga_session_id        0
# country             57
# device               0
# type                 0
# item_id              0
# date                 0
# id_y                 0
# ltv                  0
# dtype: int64

# %%
# chek the null value by presentes
df.isnull().mean()*100
# Out:
# id_x              0.000000
# name              0.000000
# brand             0.000000
# variant          84.433713
# category          0.000000
# price_in_usd      0.000000
# user_id           0.000000
# ga_session_id     0.000000
# country           0.200924
# device            0.000000
# type              0.000000
# item_id           0.000000
# date              0.000000
# id_y              0.000000
# ltv               0.000000
# dtype: float64

# %%
# chek the duplicated date
df[df.duplicated()]
# Out:
#        id_x                                 name   brand             variant  \
# 6         0         Google Land & Sea Cotton Cap  Google  Single Option Only
# 9         0         Google Land & Sea Cotton Cap  Google  Single Option Only
# 16        0         Google Land & Sea Cotton Cap  Google  Single Option Only
# 17        0         Google Land & Sea Cotton Cap  Google  Single Option Only
# 24        0         Google Land & Sea Cotton Cap  Google  Single Option Only
# ...     ...                                  ...     ...                 ...
# 25439  1085  Google F/C Long Sleeve Tee Charcoal  Google                 NaN
# 25603  1085  Google F/C Long Sleeve Tee Charcoal  Google                 NaN
# 25604  1085  Google F/C Long Sleeve Tee Charcoal  Google                 NaN
# 25605  1085  Google F/C Long Sleeve Tee Charcoal  Google                 NaN
# 26585  1119                    Google Crew Socks  Google                 NaN
#
# ...

# %%
# drop the duplicated value

df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_x, name, brand, variant, category, price_in_usd, user_id, ga_session_id, country, device, type, item_id, date, id_y, ltv]
# Index: []

# %%
# drop columns that not usefull in project

df.drop(columns=['id_x','user_id','item_id','id_y'],inplace=True)

# %%
df.head()
# Out:
#                            name   brand             variant category  \
# 0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 3  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 4  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  ga_session_id country   device            type  \
# 0            14           4933      US   mobile  begin_checkout
# 1            14            157      CA   mobile        purchase
# 2            14            773      TW  desktop     add_to_cart
# 3            14            773      TW  desktop        purchase
# 4            14           3710      US  desktop        purchase
#
#                   date  ltv
# 0  2020-11-26 01:23:38    0
# 1  2020-11-30 00:22:34    0
# 2  2020-11-30 04:29:50    0
# 3  2020-11-30 05:47:25    0
# ...

# %%
df['ltv'].value_counts()
# Out:
# ltv
# 0      26538
# 13        24
# 58        24
# 22        24
# 39        24
# 88        24
# 28        24
# 109       18
# 36        15
# 30        14
# 132       12
# 69        12
# 104       12
# 262       12
# 166       12
# 216       12
# 163       12
# 112       12
# 8         12
# 47        12
# 99        12
# 113       12
# 82        12
# 80        12
# 70        12
# 101       12
# 351       12
# 48         8
# 97         6
# 63         4
# 34         4
# 375        3
# 52         3
# 21         2
# 110        1
# 314        1
# Name: count, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#                            name   brand             variant category  \
# 0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 3  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 4  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  ga_session_id country   device            type  \
# 0            14           4933      US   mobile  begin_checkout
# 1            14            157      CA   mobile        purchase
# 2            14            773      TW  desktop     add_to_cart
# 3            14            773      TW  desktop        purchase
# 4            14           3710      US  desktop        purchase
#
#                   date  ltv
# 0  2020-11-26 01:23:38    0
# 1  2020-11-30 00:22:34    0
# 2  2020-11-30 04:29:50    0
# 3  2020-11-30 05:47:25    0
# ...

# %%
df['variant'].value_counts()
# Out:
# variant
# Single Option Only    1891
# LG                     230
#  MD                    164
#  SM                    122
#  LG                    121
# MD                      87
#  XS                     81
#  XL                     79
# SM                      65
# XL                      42
# XS                      42
#  2XL                    30
# Choose Size             23
# 6/12 MONTHS             17
#  3XL                     9
#  BLUE                    7
#  18/24 MONTHS            6
# 3/6 MONTHS               6
# 12/18 MONTHS             5
# 3XL                      5
#  4T                      5
#  RED                     4
# 2XL                      4
#  GREEN                   3
# 5/6T                     3
# NEWBORN                  2
# 2T                       2
#  5/6T                    1
#  2T                      1
#  6/12 MONTHS             1
#  3T                      1
# 3T                       1
# Name: count, dtype: int64

# %%
df['date']=pd.to_datetime(df['date']).dt.date

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2020-11-26
# 1       2020-11-30
# 2       2020-11-30
# 3       2020-11-30
# 4       2020-12-01
#            ...
# 26960   2021-01-18
# 26961   2021-01-18
# 26962   2021-01-18
# 26963   2021-01-18
# 26964   2021-01-18
# Name: date, Length: 26965, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26965 entries, 0 to 26964
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           26965 non-null  object
#  1   brand          26965 non-null  object
#  2   variant        3060 non-null   object
#  3   category       26965 non-null  object
#  4   price_in_usd   26965 non-null  int64
#  5   ga_session_id  26965 non-null  int64
#  6   country        26913 non-null  object
#  7   device         26965 non-null  object
#  8   type           26965 non-null  object
#  9   date           26965 non-null  datetime64[ns]
#  10  ltv            26965 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 2.3+ MB

# %%
df['date'].dt.year.value_counts()
# Out:
# date
# 2020    20589
# 2021     6376
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#                            name   brand             variant category  \
# 0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  ga_session_id country   device            type       date  \
# 0            14           4933      US   mobile  begin_checkout 2020-11-26
# 1            14            157      CA   mobile        purchase 2020-11-30
# 2            14            773      TW  desktop     add_to_cart 2020-11-30
#
#    ltv
# 0    0
# 1    0
# 2    0

# %%
df.isnull().sum()
# Out:
# name                 0
# brand                0
# variant          23905
# category             0
# price_in_usd         0
# ga_session_id        0
# country             52
# device               0
# type                 0
# date                 0
# ltv                  0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# name              0.000000
# brand             0.000000
# variant          88.651956
# category          0.000000
# price_in_usd      0.000000
# ga_session_id     0.000000
# country           0.192843
# device            0.000000
# type              0.000000
# date              0.000000
# ltv               0.000000
# dtype: float64

# %%
df.head()
# Out:
#                            name   brand             variant category  \
# 0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 3  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 4  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  ga_session_id country   device            type       date  \
# 0            14           4933      US   mobile  begin_checkout 2020-11-26
# 1            14            157      CA   mobile        purchase 2020-11-30
# 2            14            773      TW  desktop     add_to_cart 2020-11-30
# 3            14            773      TW  desktop        purchase 2020-11-30
# 4            14           3710      US  desktop        purchase 2020-12-01
#
#    ltv
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
df.isnull().sum()
# Out:
# name                 0
# brand                0
# variant          23905
# category             0
# price_in_usd         0
# ga_session_id        0
# country             52
# device               0
# type                 0
# date                 0
# ltv                  0
# dtype: int64

# %%
df['country'].unique()
# Out:
# array(['US', 'CA', 'TW', 'IN', 'TR', 'SG', 'IE', 'KR', 'RU', 'AU', 'FR',
#        'DE', 'CZ', 'GT', 'ES', 'CH', 'MY', 'GB', 'HK', 'CN', 'JP', 'PL',
#        'SI', 'NL', 'TH', 'DO', 'IT', 'CO', 'AR', 'AT', 'SK', 'SA', 'MX',
#        'UA', 'FI', 'NZ', 'PK', 'PE', 'CY', 'VN', 'ZA', 'BR', 'TN', 'SE',
#        'ID', 'BD', 'LK', 'PH', 'BE', 'BA', 'EG', 'GR', 'SV', 'HR', 'AE',
#        'PT', 'NO', 'JM', 'UY', 'DK', 'RS', 'IL', 'BO', 'CL', 'HN', nan,
#        'MO', 'BG', 'RO', 'HU', 'KZ', 'BY', 'KE', 'XK', 'MA', 'LB', 'EC',
#        'DZ', 'PS', 'IQ', 'KW'], dtype=object)

# %%
df['country'].value_counts()
# Out:
# country
# US    12134
# IN     2540
# CA     1851
# GB      984
# ES      679
#       ...
# RS        3
# BO        3
# GT        1
# JM        1
# KW        1
# Name: count, Length: 80, dtype: int64

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %%
df.isnull().sum()
# Out:
# name                 0
# brand                0
# variant          23905
# category             0
# price_in_usd         0
# ga_session_id        0
# country              0
# device               0
# type                 0
# date                 0
# ltv                  0
# dtype: int64

# %%
df.head()
# Out:
#                            name   brand             variant category  \
# 0  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 1  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 2  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 3  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
# 4  Google Land & Sea Cotton Cap  Google  Single Option Only  Apparel
#
#    price_in_usd  ga_session_id country   device            type       date  \
# 0            14           4933      US   mobile  begin_checkout 2020-11-26
# 1            14            157      CA   mobile        purchase 2020-11-30
# 2            14            773      TW  desktop     add_to_cart 2020-11-30
# 3            14            773      TW  desktop        purchase 2020-11-30
# 4            14           3710      US  desktop        purchase 2020-12-01
#
#    ltv
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
df['variant'].value_counts().head(13)
# Out:
# variant
# Single Option Only    1891
# LG                     230
#  MD                    164
#  SM                    122
#  LG                    121
# MD                      87
#  XS                     81
#  XL                     79
# SM                      65
# XL                      42
# XS                      42
#  2XL                    30
# Choose Size             23
# Name: count, dtype: int64

# %%
a=[]
for i in df['variant']:

    if i in df['variant'].value_counts().head(13).index:
        a.append(i)
    else:
        a.append('Other Variant')

# %%
df['Variant2']=pd.DataFrame(a)

# %%
df
# Out:
#                                name   brand             variant    category  \
# 0      Google Land & Sea Cotton Cap  Google  Single Option Only     Apparel
# 1      Google Land & Sea Cotton Cap  Google  Single Option Only     Apparel
# 2      Google Land & Sea Cotton Cap  Google  Single Option Only     Apparel
# 3      Google Land & Sea Cotton Cap  Google  Single Option Only     Apparel
# 4      Google Land & Sea Cotton Cap  Google  Single Option Only     Apparel
# ...                             ...     ...                 ...         ...
# 26960   Google Men's Softshell Moss  Google                  LG     Apparel
# 26961            Gift Card - $50.00  Google                 NaN  Gift Cards
# 26962            Gift Card - $25.00  Google                 NaN  Gift Cards
# 26963            Gift Card - $10.00  Google                 NaN  Gift Cards
# 26964           Gift Card - $250.00  Google                 NaN  Gift Cards
#
# ...

# %%
df.drop(columns='variant',inplace=True)

# %%
df.head()
# Out:
#                            name   brand category  price_in_usd  ga_session_id  \
# 0  Google Land & Sea Cotton Cap  Google  Apparel            14           4933
# 1  Google Land & Sea Cotton Cap  Google  Apparel            14            157
# 2  Google Land & Sea Cotton Cap  Google  Apparel            14            773
# 3  Google Land & Sea Cotton Cap  Google  Apparel            14            773
# 4  Google Land & Sea Cotton Cap  Google  Apparel            14           3710
#
#   country   device            type       date  ltv            Variant2
# 0      US   mobile  begin_checkout 2020-11-26    0  Single Option Only
# 1      CA   mobile        purchase 2020-11-30    0  Single Option Only
# 2      TW  desktop     add_to_cart 2020-11-30    0  Single Option Only
# 3      TW  desktop        purchase 2020-11-30    0  Single Option Only
# 4      US  desktop        purchase 2020-12-01    0  Single Option Only

# %%
df.isnull().sum()
# Out:
# name             0
# brand            0
# category         0
# price_in_usd     0
# ga_session_id    0
# country          0
# device           0
# type             0
# date             0
# ltv              0
# Variant2         0
# dtype: int64

# %%
df['name']=df['name'].str.split(' ').str[0] +' '+df['name'].str.split(' ').str[1]

# %%
df.name.value_counts().head(40)
# Out:
# name
# Google Land         1601
# Android Iconic      1175
# Google Women's       964
# Google Crewneck      888
# Google Tee           880
# Google Campus        816
# Google F/C           791
# Android Large        699
# Google Navy          581
# Google Cambridge     575
# Google Zip           531
# Super G              516
# Google Small         444
# Google Youth         418
# YouTube Icon         417
# Google Men's         411
# Google NYC           409
# Google Badge         406
# Android SM           404
# Google Leather       396
# Google Speckled      362
# Google Pen           328
# Google Sherpa        321
# YouTube Women's      306
# Android Techie       304
# Android Small        302
# Android Super        299
# Google Mural         279
# Google Red           259
# Google Toddler       254
# Google Black         250
# Google Heathered     246
# Google Cork          238
# YouTube Twill        232
# Google Crew          230
# YouTube Leather      229
# ...

# %%
df
# Out:
#                name   brand    category  price_in_usd  ga_session_id country  \
# 0       Google Land  Google     Apparel            14           4933      US
# 1       Google Land  Google     Apparel            14            157      CA
# 2       Google Land  Google     Apparel            14            773      TW
# 3       Google Land  Google     Apparel            14            773      TW
# 4       Google Land  Google     Apparel            14           3710      US
# ...             ...     ...         ...           ...            ...     ...
# 26960  Google Men's  Google     Apparel            99           9205      CZ
# 26961     Gift Card  Google  Gift Cards            63           1141      CA
# 26962     Gift Card  Google  Gift Cards            31           1141      CA
# 26963     Gift Card  Google  Gift Cards            13           1141      CA
# 26964     Gift Card  Google  Gift Cards           313           1141      CA
#
# ...

# %%
df['type'].value_counts()
# Out:
# type
# add_to_cart       25032
# begin_checkout     1452
# purchase            481
# Name: count, dtype: int64

# %%
df['type']=df['type'].str.capitalize()

# %%
df
# Out:
#                name   brand    category  price_in_usd  ga_session_id country  \
# 0       Google Land  Google     Apparel            14           4933      US
# 1       Google Land  Google     Apparel            14            157      CA
# 2       Google Land  Google     Apparel            14            773      TW
# 3       Google Land  Google     Apparel            14            773      TW
# 4       Google Land  Google     Apparel            14           3710      US
# ...             ...     ...         ...           ...            ...     ...
# 26960  Google Men's  Google     Apparel            99           9205      CZ
# 26961     Gift Card  Google  Gift Cards            63           1141      CA
# 26962     Gift Card  Google  Gift Cards            31           1141      CA
# 26963     Gift Card  Google  Gift Cards            13           1141      CA
# 26964     Gift Card  Google  Gift Cards           313           1141      CA
#
# ...

# %%
df['country'].value_counts()
# Out:
# country
# US    12186
# IN     2540
# CA     1851
# GB      984
# ES      679
#       ...
# RS        3
# BO        3
# GT        1
# JM        1
# KW        1
# Name: count, Length: 80, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Apparel                    10638
# New                         2539
# Accessories                 2415
# Shop by Brand               1930
# Campus Collection           1560
# Clearance                   1359
# Lifestyle                   1076
# Office                      1043
# Drinkware                    978
# Bags                         975
# Uncategorized Items          812
# Notebooks & Journals         624
# Stationery                   275
# Writing Instruments          221
# Google                       190
# Small Goods                  172
# Electronics Accessories       82
# Fun                           53
# Eco-Friendly                  17
# Gift Cards                     6
# Name: count, dtype: int64

# %%
df.to_csv('google_chean',index=False)
